# %% [markdown]
# # WeatherPy
#
# Observations:
#
# 1. Temperature increases as location approaches the equator at 0 latitude.
#
# 2. Humidity, cloudiness, and windspeed do not show a relationship to latitude.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
from api_keys import api_key 

# Incorporate citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List to hold lat_lngs and cities
lat_lngs = []
cities = []

# Create random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique then add it to cities list
    if city not in cities:
        cities.append(city)

# Print city count
num = len(cities)

# %%
# Base URL for Weathermap API call
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Build query URL
query_url = f"{base_url}q={city}&APPID={api_key}"

# %%
#Empty lists to append
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
date = []
country = []
names = []

LastRow = 0

# %%
#For loop to perform API calls on cities

for city in cities:  
    response = requests.get(f"{base_url}q={city}&APPID={api_key}").json() 
    
    
    try: 
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        city_id = response['id']
        names = response['name']
        
        print(f"Processed {LastRow} of {num} | {city} with id {city_id}")
       
       
        #Delay next call by one second to stay within API call criteria
        time.sleep(1.01)
        
        #Move to next row 
        LastRow= LastRow + 1
        
       
    #If not found then print message.
    except:
        print(f"{city} not found.")
        pass
# Out:
# Processed 0 of 284 | gimli with id 5961417
# Processed 1 of 284 | punta arenas with id 3874787
# Processed 2 of 284 | richards bay with id 962367
# Processed 3 of 284 | hulyaypole with id 707898
# Processed 4 of 284 | narsaq with id 3421719
# Processed 5 of 284 | vernon with id 6173864
# taolanaro not found.
# Processed 6 of 284 | hanko with id 659101
# Processed 7 of 284 | aranos with id 3358666
# vaitupu not found.
# Processed 8 of 284 | mataura with id 6201424
# Processed 9 of 284 | hermanus with id 3366880
# Processed 10 of 284 | rikitea with id 4030556
# Processed 11 of 284 | busselton with id 2075265
# Processed 12 of 284 | puerto ayora with id 3652764
# Processed 13 of 284 | fortuna with id 5563839
# Processed 14 of 284 | trelew with id 3833883
# Processed 15 of 284 | avarua with id 4035715
# Processed 16 of 284 | jamestown with id 2069194
# Processed 17 of 284 | poronaysk with id 2121909
# bolungarvik not found.
# Processed 18 of 284 | tabou with id 2281120
# Processed 19 of 284 | torbay with id 6167817
# Processed 20 of 284 | ponta do sol with id 3453439
# Processed 21 of 284 | bluff with id 2175403
# Processed 22 of 284 | albany with id 5106834
# Processed 23 of 284 | marsh harbour with id 3571913
# olafsvik not found.
# Processed 24 of 284 | tasiilaq with id 3424607
# Processed 25 of 284 | manadhoo with id 1337618
# Processed 26 of 284 | alofi with id 4036284
# Processed 27 of 284 | teya with id 3526662
# Processed 28 of 284 | ushuaia with id 3833367
# Processed 29 of 284 | vaini with id 1273574
# Processed 30 of 284 | cherskiy with id 2126199
# Processed 31 of 284 | yellowknife with id 6185377
# Processed 32 of 284 | belmonte with id 8010472
# Processed 33 of 284 | sogod with id 1685925
# Processed 34 of 284 | san cristobal with id 3609418
# Processed 35 of 284 | jimo with id 1805757
# warqla not found.
# Processed 36 of 284 | calderitas with id 3531816
# Processed 37 of 284 | cape town with id 3369157
# Processed 38 of 284 | kapaa with id 5848280
# illoqqortoormiut not found.
# Processed 39 of 284 | okhotsk with id 2122605
# chapar not found.
# Processed 40 of 284 | mahebourg with id 934322
# Processed 41 of 284 | nikolskoye with id 546105
# khonuu not found.
# Processed 42 of 284 | port elizabeth with id 4501427
# Processed 43 of 284 | castro with id 3896218
# Processed 44 of 284 | evensk with id 2125693
# Processed 45 of 284 | tuktoyaktuk with id 6170031
# Processed 46 of 284 | dali with id 1814092
# Processed 47 of 284 | norton with id 4945911
# Processed 48 of 284 | hofn with id 2630299
# Processed 49 of 284 | zeya with id 2012593
# Processed 50 of 284 | kieta with id 2094027
# Processed 51 of 284 | salalah with id 286621
# Processed 52 of 284 | qaanaaq with id 3831208
# Processed 53 of 284 | inta with id 1505579
# Processed 54 of 284 | naze with id 2337542
# Processed 55 of 284 | kidal with id 2455290
# barentsburg not found.
# Processed 56 of 284 | najran with id 103630
# Processed 57 of 284 | vizinga with id 473263
# Processed 58 of 284 | bobcaygeon with id 8125787
# Processed 59 of 284 | hamilton with id 5969785
# Processed 60 of 284 | san patricio with id 3437029
# borlange not found.
# Processed 61 of 284 | benicarlo with id 3128273
# Processed 62 of 284 | seymchan with id 2121373
# Processed 63 of 284 | port alfred with id 964432
# Processed 64 of 284 | cabinda with id 2243271
# Processed 65 of 284 | tiksi with id 2015306
# Processed 66 of 284 | grand gaube with id 934479
# Processed 67 of 284 | nome with id 4732862
# Processed 68 of 284 | atuona with id 4020109
# Processed 69 of 284 | cabo san lucas with id 3985710
# Processed 70 of 284 | primorka with id 505256
# Processed 71 of 284 | hohhot with id 2036892
# sentyabrskiy not found.
# Processed 72 of 284 | creaca with id 680298
# Processed 73 of 284 | shimoda with id 1852357
# Processed 74 of 284 | khani with id 610864
# Processed 75 of 284 | moussoro with id 2427336
# Processed 76 of 284 | altay with id 1529651
# Processed 77 of 284 | vao with id 588365
# Processed 78 of 284 | kenai with id 5866063
# korla not found.
# Processed 79 of 284 | cayenne with id 3382160
# matameye not found.
# Processed 80 of 284 | mantua with id 3174050
# Processed 81 of 284 | qingyuan with id 1905324
# Processed 82 of 284 | goure with id 2444219
# Processed 83 of 284 | east london with id 1006984
# Processed 84 of 284 | lubango with id 3347762
# Processed 85 of 284 | henderson with id 5505411
# Processed 86 of 284 | amahai with id 1651591
# Processed 87 of 284 | nanortalik with id 3421765
# Processed 88 of 284 | lavrentiya with id 4031637
# Processed 89 of 284 | avera with id 4231997
# Processed 90 of 284 | carnarvon with id 1014034
# Processed 91 of 284 | pangnirtung with id 6096551
# Processed 92 of 284 | kaitangata with id 2208248
# Processed 93 of 284 | vila franca do campo with id 3372472
# Processed 94 of 284 | georgetown with id 3378644
# Processed 95 of 284 | orotukan with id 2122414
# tumannyy not found.
# Processed 96 of 284 | pevek with id 2122090
# Processed 97 of 284 | bethel with id 5880568
# kirya not found.
# Processed 98 of 284 | dunda with id 1253628
# bobo dioulasso not found.
# Processed 99 of 284 | yenagoa with id 2318123
# Processed 100 of 284 | vestmanna with id 2610343
# Processed 101 of 284 | ahipara with id 2194098
# Processed 102 of 284 | arcachon with id 3037253
# Processed 103 of 284 | barrow with id 3833859
# Processed 104 of 284 | pozo colorado with id 3437443
# Processed 105 of 284 | khatanga with id 2022572
# Processed 106 of 284 | burnie with id 2173125
# Processed 107 of 284 | port hardy with id 6111862
# Processed 108 of 284 | palmer with id 2067070
# vastervik not found.
# Processed 109 of 284 | mehamn with id 778707
# mys shmidta not found.
# Processed 110 of 284 | kathmandu with id 1283240
# westpunt not found.
# Processed 111 of 284 | timra with id 2669047
# Processed 112 of 284 | tiarei with id 4033356
# Processed 113 of 284 | klaksvik with id 2618795
# Processed 114 of 284 | hobart with id 2163355
# Processed 115 of 284 | cidreira with id 3466165
# Processed 116 of 284 | namibe with id 3347019
# Processed 117 of 284 | iqaluit with id 5983720
# Processed 118 of 284 | chapais with id 5919850
# Processed 119 of 284 | saskylakh with id 2017155
# Processed 120 of 284 | ulaanbaatar with id 2028462
# Processed 121 of 284 | umm lajj with id 100926
# Processed 122 of 284 | tabuk with id 1684803
# Processed 123 of 284 | itoman with id 1861280
# Processed 124 of 284 | mar del plata with id 3863379
# Processed 125 of 284 | waddan with id 2209055
# Processed 126 of 284 | mayo with id 6068416
# Processed 127 of 284 | xuddur with id 49747
# kemijarvi not found.
# Processed 128 of 284 | ust-tsilma with id 477940
# Processed 129 of 284 | coquimbo with id 3893629
# Processed 130 of 284 | bredasdorp with id 1015776
# Processed 131 of 284 | sitka with id 4267710
# Processed 132 of 284 | margate with id 2158744
# Processed 133 of 284 | hilo with id 5855927
# Processed 134 of 284 | bulungu with id 2316259
# Processed 135 of 284 | tari with id 2322495
# Processed 136 of 284 | leningradskiy with id 2123814
# Processed 137 of 284 | toora-khem with id 1489401
# Processed 138 of 284 | winchester with id 2633858
# Processed 139 of 284 | huarmey with id 3939168
# Processed 140 of 284 | fort nelson with id 5955902
# Processed 141 of 284 | chokurdakh with id 2126123
# Processed 142 of 284 | marsa matruh with id 352733
# Processed 143 of 284 | kaniama with id 214389
# Processed 144 of 284 | meulaboh with id 1214488
# Processed 145 of 284 | saint-leu with id 6690297
# Processed 146 of 284 | rexburg with id 5605242
# Processed 147 of 284 | kavieng with id 2094342
# sandavagur not found.
# Processed 148 of 284 | aykhal with id 2027296
# stornoway not found.
# Processed 149 of 284 | riyadh with id 108410
# lolua not found.
# Processed 150 of 284 | nantucket with id 4944903
# Processed 151 of 284 | seoul with id 1835848
# Processed 152 of 284 | ancud with id 3899695
# Processed 153 of 284 | lodja with id 211647
# Processed 154 of 284 | butaritari with id 2110227
# urumqi not found.
# Processed 155 of 284 | saint george with id 262462
# Processed 156 of 284 | adrar with id 2508813
# Processed 157 of 284 | saint-augustin with id 6138501
# Processed 158 of 284 | codrington with id 2160063
# Processed 159 of 284 | esperance with id 2071860
# Processed 160 of 284 | grand-santi with id 3381538
# Processed 161 of 284 | port lincoln with id 2063036
# tsihombe not found.
# Processed 162 of 284 | chuy with id 3443061
# Processed 163 of 284 | saldanha with id 2737599
# Processed 164 of 284 | mackay with id 5921525
# Processed 165 of 284 | talnakh with id 1490256
# Processed 166 of 284 | bambous virieux with id 1106677
# Processed 167 of 284 | muzaffarpur with id 1262330
# Processed 168 of 284 | barcelos with id 3665098
# Processed 169 of 284 | norman wells with id 6089245
# Processed 170 of 284 | arlit with id 2447513
# Processed 171 of 284 | beeskow with id 2951528
# tubruq not found.
# Processed 172 of 284 | nisia floresta with id 3393922
# Processed 173 of 284 | kwekwe with id 888710
# samusu not found.
# Processed 174 of 284 | eureka with id 5563397
# mentok not found.
# Processed 175 of 284 | batagay-alyta with id 2027042
# Processed 176 of 284 | kingisepp with id 548602
# Processed 177 of 284 | praia da vitoria with id 3372760
# Processed 178 of 284 | mattru with id 2409215
# Processed 179 of 284 | rio verde de mato grosso with id 3451051
# Processed 180 of 284 | gambela with id 337405
# Processed 181 of 284 | trincomalee with id 1226260
# Processed 182 of 284 | deputatskiy with id 2028164
# Processed 183 of 284 | pleshanovo with id 514171
# Processed 184 of 284 | sao filipe with id 3374210
# Processed 185 of 284 | arraial do cabo with id 3471451
# Processed 186 of 284 | srednekolymsk with id 2121025
# Processed 187 of 284 | lebu with id 344979
# Processed 188 of 284 | northam with id 2064550
# Processed 189 of 284 | bilibino with id 2126682
# Processed 190 of 284 | qasigiannguit with id 3420768
# Processed 191 of 284 | provideniya with id 4031574
# Processed 192 of 284 | faanui with id 4034551
# Processed 193 of 284 | maple creek with id 6065592
# Processed 194 of 284 | stokmarknes with id 3136690
# Processed 195 of 284 | winslow with id 2633808
# Processed 196 of 284 | kiama with id 2161515
# Processed 197 of 284 | yumen with id 1528998
# Processed 198 of 284 | pitanga with id 3453478
# saint-pascal not found.
# bokoro not found.
# Processed 199 of 284 | agadez with id 2448085
# Processed 200 of 284 | tual with id 1623197
# Processed 201 of 284 | new norfolk with id 2155415
# Processed 202 of 284 | keti bandar with id 1174451
# Processed 203 of 284 | tautira with id 4033557
# gurupa not found.
# Processed 204 of 284 | barreirinha with id 3406202
# Processed 205 of 284 | saint-philippe with id 6138908
# Processed 206 of 284 | prata with id 3452440
# Processed 207 of 284 | dukat with id 3184575
# tabiauea not found.
# Processed 208 of 284 | beyneu with id 610298
# Processed 209 of 284 | punakha with id 1252495
# Processed 210 of 284 | kaliyaganj with id 1268383
# Processed 211 of 284 | manaure with id 3675504
# Processed 212 of 284 | kruisfontein with id 986717
# Processed 213 of 284 | lagoa with id 2267254
# Processed 214 of 284 | lompoc with id 5367788
# Processed 215 of 284 | viedma with id 3832899
# Processed 216 of 284 | balikpapan with id 1650527
# Processed 217 of 284 | russell with id 4278471
# Processed 218 of 284 | bismarck with id 5688025
# Processed 219 of 284 | constitucion with id 4011743
# Processed 220 of 284 | batemans bay with id 2176639
# Processed 221 of 284 | bambanglipuro with id 1650434
# attawapiskat not found.
# Processed 222 of 284 | hithadhoo with id 1282256
# Processed 223 of 284 | akhisar with id 324698
# Processed 224 of 284 | vestmannaeyjar with id 3412093
# kamenskoye not found.
# Processed 225 of 284 | te anau with id 2181625
# Processed 226 of 284 | high level with id 5975004
# Processed 227 of 284 | guarapuava with id 3461879
# saleaula not found.
# Processed 228 of 284 | dawlatabad with id 1142226
# Processed 229 of 284 | sinfra with id 2281606
# Processed 230 of 284 | zhigansk with id 2012530
# Processed 231 of 284 | ribeira grande with id 3372707
# Processed 232 of 284 | mount gambier with id 2156643
# tsienyane not found.
# Processed 233 of 284 | longyearbyen with id 2729907
# Processed 234 of 284 | carutapera with id 3402648
# Processed 235 of 284 | birjand with id 140463
# Processed 236 of 284 | zhuanghe with id 1784055
# Processed 237 of 284 | turinsk with id 1488933
# yanchukan not found.
# Processed 238 of 284 | ongandjera with id 3354178
# Processed 239 of 284 | isangel with id 2136825
# Processed 240 of 284 | lahad datu with id 1733953
# Processed 241 of 284 | labuhan with id 1641899
# Processed 242 of 284 | thompson with id 6165406
# Processed 243 of 284 | namatanai with id 2090021
# Processed 244 of 284 | geraldton with id 5960603
# Processed 245 of 284 | ilulissat with id 3423146
# Processed 246 of 284 | nabannagan with id 1698914

# %%
weatherpy = {    
    "City": names, 
    "Country":country,
    "Date":date,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness":cloudiness,
    "Wind Speed":wind_speed}

# Create dataframe from dictionary
weather_df = pd.DataFrame(weatherpy)

# Display dataframe headers 
weather_df.head()
# Out:
#          City Country        Date    Lat    Lng  Max Temp  Humidity  \
# 0  Nabannagan      CA  1562801552  50.63 -96.99   299.820        33
# 1  Nabannagan      CL  1562801554 -53.16 -70.91   276.150        93
# 2  Nabannagan      ZA  1562801555 -28.77  32.06   294.668        79
# 3  Nabannagan      UA  1562801556  47.67  36.26   288.168        74
# 4  Nabannagan      GL  1562801308  60.91 -46.05   286.150        54
#
#    Cloudiness  Wind Speed
# 0          17        1.79
# 1          90        2.60
# 2           0        4.44
# 3         100        1.93
# 4          14        6.70

# %%
#Save dataframe to CSV
weather_df.to_csv("weather_df.csv")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], c=weather_df["Max Temp"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (F)")
plt.xlabel("Latitude")
plt.ylabel("Max. Temperature (F)")

#Insert grid lines
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Humidity"], c=weather_df["Humidity"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humdity (%)")

#Insert grid lines
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], c=weather_df["Cloudiness"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

#Insert grid lines
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], c=weather_df["Wind Speed"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

#Insert grid lines
plt.grid(True)

# Save the figure
plt.savefig("Wind Speed_vs_Latitude.png")

# Show plot
plt.show()
